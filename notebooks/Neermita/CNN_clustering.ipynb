# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16

# %%
import ssl
import urllib.request

# Bypass SSL certificate verification
# ssl._create_default_https_context = ssl._create_unverified_context

# # Download CIFAR-10 dataset
# url = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# urllib.request.urlretrieve(url, "cifar-10-python.tar.gz")

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
# Preprocess the data (normalize to [0, 1])
x_train = X_train.astype('float32') / 255.
x_test = X_test.astype('float32') / 255.
print(x_train.shape)
print(x_test.shape)
print(x_train)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# [[[[0.23137255 0.24313726 0.24705882]
#    [0.16862746 0.18039216 0.1764706 ]
#    [0.19607843 0.1882353  0.16862746]
#    ...
#    [0.61960787 0.5176471  0.42352942]
#    [0.59607846 0.49019608 0.4       ]
#    [0.5803922  0.4862745  0.40392157]]
#
#   [[0.0627451  0.07843138 0.07843138]
#    [0.         0.         0.        ]
#    [0.07058824 0.03137255 0.        ]
#    ...
#    [0.48235294 0.34509805 0.21568628]
#    [0.46666667 0.3254902  0.19607843]
#    [0.47843137 0.34117648 0.22352941]]
#
#   [[0.09803922 0.09411765 0.08235294]
#    [0.0627451  0.02745098 0.        ]
#    [0.19215687 0.10588235 0.03137255]
#    ...
#    [0.4627451  0.32941177 0.19607843]
#    [0.47058824 0.32941177 0.19607843]
#    [0.42745098 0.28627452 0.16470589]]
#
#   ...
#
#   [[0.8156863  0.6666667  0.3764706 ]
#    [0.7882353  0.6        0.13333334]
#    [0.7764706  0.6313726  0.10196079]
#    ...
#    [0.627451   0.52156866 0.27450982]
#    [0.21960784 0.12156863 0.02745098]
#    [0.20784314 0.13333334 0.07843138]]
#
#   [[0.7058824  0.54509807 0.3764706 ]
#    [0.6784314  0.48235294 0.16470589]
#    [0.7294118  0.5647059  0.11764706]
#    ...
#    [0.72156864 0.5803922  0.36862746]
#    [0.38039216 0.24313726 0.13333334]
#    [0.3254902  0.20784314 0.13333334]]
#
#   [[0.69411767 0.5647059  0.45490196]
#    [0.65882355 0.5058824  0.36862746]
#    [0.7019608  0.5568628  0.34117648]
#    ...
#    [0.84705883 0.72156864 0.54901963]
#    [0.5921569  0.4627451  0.32941177]
#    [0.48235294 0.36078432 0.28235295]]]
#
#
#  [[[0.6039216  0.69411767 0.73333335]
#    [0.49411765 0.5372549  0.53333336]
#    [0.4117647  0.40784314 0.37254903]
#    ...
#    [0.35686275 0.37254903 0.2784314 ]
#    [0.34117648 0.3529412  0.2784314 ]
#    [0.30980393 0.31764707 0.27450982]]
#
#   [[0.54901963 0.627451   0.6627451 ]
#    [0.5686275  0.6        0.6039216 ]
#    [0.49019608 0.49019608 0.4627451 ]
#    ...
#    [0.3764706  0.3882353  0.30588236]
#    [0.3019608  0.3137255  0.24313726]
#    [0.2784314  0.28627452 0.23921569]]
#
#   [[0.54901963 0.60784316 0.6431373 ]
#    [0.54509807 0.57254905 0.58431375]
#    [0.4509804  0.4509804  0.4392157 ]
#    ...
#    [0.30980393 0.32156864 0.2509804 ]
#    [0.26666668 0.27450982 0.21568628]
#    [0.2627451  0.27058825 0.21568628]]
#
#   ...
#
#   [[0.6862745  0.654902   0.6509804 ]
#    [0.6117647  0.6039216  0.627451  ]
#    [0.6039216  0.627451   0.6666667 ]
#    [0.54901963 0.5294118  0.49803922]
#    [0.5176471  0.49803922 0.47058824]
#    ...
#    [0.8784314  0.87058824 0.85490197]
#    [0.9019608  0.89411765 0.88235295]
#    [0.94509804 0.94509804 0.93333334]]
#
#   [[0.5372549  0.5176471  0.49411765]
#    [0.50980395 0.49803922 0.47058824]
#    [0.49019608 0.4745098  0.4509804 ]
#    ...
#    [0.70980394 0.7058824  0.69803923]
#    [0.7921569  0.7882353  0.7764706 ]
#    [0.83137256 0.827451   0.8117647 ]]
#
#   [[0.47843137 0.46666667 0.44705883]
#    [0.4627451  0.45490196 0.43137255]
#    [0.47058824 0.45490196 0.43529412]
#    ...
#    [0.7019608  0.69411767 0.6784314 ]
#    [0.6431373  0.6431373  0.63529414]
#    [0.6392157  0.6392157  0.6313726 ]]]]

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=x_train.shape[1:])

# Extract features from the pre-trained VGG16 model
features_train = base_model.predict(x_train)
features_test = base_model.predict(x_test)
# Out:
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 162s 103ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 112ms/step

# %%
features_train = features_train.reshape(features_train.shape[0], -1)
print(features_train.shape)
print(features_train)
# Out:
# (50000, 512)
# [[0.1017662  0.         0.84405106 ... 0.         0.39529693 0.        ]
#  [0.9722147  0.         0.58577275 ... 0.         0.7981688  0.        ]
#  [0.3126762  0.         0.22860837 ... 0.28975034 1.1120024  0.        ]
#  ...
#  [0.23091513 0.         0.118855   ... 0.2488248  0.5913635  0.        ]
#  [0.         0.         0.2835029  ... 0.         0.59139776 0.        ]
#  [0.         0.         0.7414491  ... 0.         0.98388207 0.        ]]

# %%
features_test = features_test.reshape(features_test.shape[0], -1)
print(features_test.shape)
print(features_test)
# Out:
# (10000, 512)
# [[0.2865308  0.         1.2196426  ... 0.09188334 0.50850433 0.        ]
#  [0.43598855 0.         0.68447256 ... 0.22535783 0.50218326 0.        ]
#  [0.29467416 0.         0.         ... 0.31027997 0.62160414 0.        ]
#  ...
#  [0.         0.         1.1950839  ... 0.18938634 0.32439792 0.        ]
#  [0.7446521  0.         1.1791041  ... 0.17728972 0.50125146 0.        ]
#  [0.9902093  0.         1.0467237  ... 0.0069061  0.801184   0.        ]]

# %%
num_clusters = 10  #10 clusters for CIFAR-10 dataset
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(features_train)

# Use KMeans to predict cluster assignments for test data
cluster_assignments_test = kmeans.predict(features_test)
# Out:
# C:\Users\91982\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
centroids = kmeans.cluster_centers_
print(centroids)
print(centroids.shape)
# Reconstruct the image from the cluster centroids
reconstructed_images = centroids[cluster_assignments_test]
print(reconstructed_images.shape)
print(cluster_assignments_test.shape)
print(y_test.shape)
y_test=np.ravel(y_test)
# Out:
# [[2.92101890e-01 1.00408215e-09 4.13032919e-01 ... 2.02255398e-01
#   7.94649422e-01 2.35741027e-09]
#  [1.54785722e-01 7.31385080e-06 3.47467870e-01 ... 3.59863788e-02
#   5.67595422e-01 3.92901711e-09]
#  [7.76232898e-01 8.87666829e-10 6.60345018e-01 ... 1.00222364e-01
#   7.33931065e-01 1.47515791e-04]
#  ...
#  [4.72731650e-01 2.59247608e-05 6.67954803e-01 ... 2.83946633e-01
#   5.93189657e-01 2.00868992e-04]
#  [6.50744200e-01 1.16807397e-03 8.28194618e-01 ... 1.41202673e-01
#   4.11073864e-01 1.39591470e-03]
#  [6.00492537e-01 7.05767889e-10 6.32232666e-01 ... 7.10819662e-02
#   5.32743335e-01 1.64557248e-04]]
# (10, 512)
# (10000, 512)
# (10000,)
# (10000,)

# %%
from scipy.optimize import linear_sum_assignment
# Calculate cost matrix (negative of the confusion matrix)
confusion_matrix = np.zeros((num_clusters, num_clusters))
for i in range(num_clusters):
    for j in range(num_clusters):
        confusion_matrix[i, j] = np.sum((cluster_assignments_test == i) & (y_test == j))

cost_matrix = -confusion_matrix

# Use Hungarian algorithm to find best matching between clusters and true labels
row_indices, col_indices = linear_sum_assignment(cost_matrix)

# Extract matching indices
matching_indices = col_indices

# Match predicted cluster assignments to true labels
cluster_assignments_matched = np.array([matching_indices[cluster] for cluster in cluster_assignments_test])

# Calculate accuracy
accuracy = np.mean(cluster_assignments_matched == y_test)
print(f"\nAccuracy: {accuracy}")
# Out:
# Accuracy: 0.2223

# %%
np.random.seed(42)
random_indices = np.random.choice(len(x_test), 100, replace=False)

# Print predicted and true cluster assignments for 5 examples
for idx in random_indices:
    print(f"Example {idx}: Predicted Cluster - {cluster_assignments_test[idx]}, True Label - {y_test[idx]}")
# Out:
# Example 6252: Predicted Cluster - 0, True Label - 2
# Example 4684: Predicted Cluster - 4, True Label - 1
# Example 1731: Predicted Cluster - 4, True Label - 5
# Example 4742: Predicted Cluster - 7, True Label - 8
# Example 4521: Predicted Cluster - 1, True Label - 9
# Example 6340: Predicted Cluster - 0, True Label - 3
# Example 576: Predicted Cluster - 2, True Label - 8
# Example 5202: Predicted Cluster - 1, True Label - 9
# Example 6363: Predicted Cluster - 1, True Label - 0
# Example 439: Predicted Cluster - 6, True Label - 1
# Example 2750: Predicted Cluster - 9, True Label - 5
# Example 7487: Predicted Cluster - 1, True Label - 1
# Example 5272: Predicted Cluster - 3, True Label - 3
# Example 5653: Predicted Cluster - 4, True Label - 5
# Example 3999: Predicted Cluster - 3, True Label - 9
# Example 6033: Predicted Cluster - 2, True Label - 2
# Example 582: Predicted Cluster - 6, True Label - 8
# Example 9930: Predicted Cluster - 3, True Label - 8
# Example 7051: Predicted Cluster - 0, True Label - 3
# Example 8158: Predicted Cluster - 1, True Label - 8
# Example 9896: Predicted Cluster - 1, True Label - 4
# Example 2249: Predicted Cluster - 1, True Label - 0
# Example 4640: Predicted Cluster - 2, True Label - 2
# Example 9485: Predicted Cluster - 9, True Label - 7
# Example 4947: Predicted Cluster - 8, True Label - 5
# Example 9920: Predicted Cluster - 9, True Label - 6
# Example 1963: Predicted Cluster - 5, True Label - 2
# Example 8243: Predicted Cluster - 9, True Label - 4
# Example 6590: Predicted Cluster - 2, True Label - 5
# Example 8847: Predicted Cluster - 9, True Label - 5
# Example 321: Predicted Cluster - 6, True Label - 5
# Example 2678: Predicted Cluster - 2, True Label - 0
# Example 4625: Predicted Cluster - 9, True Label - 4
# Example 4949: Predicted Cluster - 1, True Label - 1
# Example 8328: Predicted Cluster - 4, True Label - 7
# Example 3337: Predicted Cluster - 9, True Label - 7
# Example 5589: Predicted Cluster - 9, True Label - 2
# Example 251: Predicted Cluster - 6, True Label - 3
# Example 3973: Predicted Cluster - 1, True Label - 9
# Example 6630: Predicted Cluster - 3, True Label - 7
# Example 5547: Predicted Cluster - 1, True Label - 2
# Example 35: Predicted Cluster - 4, True Label - 2
# Example 8362: Predicted Cluster - 6, True Label - 3
# Example 1513: Predicted Cluster - 7, True Label - 6
# Example 9317: Predicted Cluster - 7, True Label - 6
# Example 39: Predicted Cluster - 7, True Label - 5
# Example 4819: Predicted Cluster - 7, True Label - 5
# Example 3465: Predicted Cluster - 7, True Label - 6
# Example 1760: Predicted Cluster - 1, True Label - 0
# Example 2304: Predicted Cluster - 7, True Label - 6
# Example 3723: Predicted Cluster - 1, True Label - 1
# Example 8284: Predicted Cluster - 9, True Label - 2
# Example 4993: Predicted Cluster - 0, True Label - 7
# Example 8127: Predicted Cluster - 1, True Label - 9
# Example 3032: Predicted Cluster - 7, True Label - 2
# Example 7938: Predicted Cluster - 7, True Label - 2
# Example 3039: Predicted Cluster - 3, True Label - 1
# Example 9655: Predicted Cluster - 5, True Label - 8
# Example 2545: Predicted Cluster - 3, True Label - 4
# Example 2592: Predicted Cluster - 0, True Label - 2
# Example 1188: Predicted Cluster - 5, True Label - 0
# Example 7966: Predicted Cluster - 0, True Label - 7
# Example 6077: Predicted Cluster - 5, True Label - 0
# Example 107: Predicted Cluster - 0, True Label - 6
# Example 1315: Predicted Cluster - 5, True Label - 4
# Example 8187: Predicted Cluster - 9, True Label - 5
# Example 2753: Predicted Cluster - 6, True Label - 7
# Example 9753: Predicted Cluster - 4, True Label - 3
# Example 6231: Predicted Cluster - 3, True Label - 8
# Example 2876: Predicted Cluster - 5, True Label - 9
# Example 5323: Predicted Cluster - 8, True Label - 1
# Example 799: Predicted Cluster - 5, True Label - 2
# Example 3570: Predicted Cluster - 8, True Label - 3
# Example 2894: Predicted Cluster - 6, True Label - 6
# Example 2927: Predicted Cluster - 5, True Label - 8
# Example 8178: Predicted Cluster - 6, True Label - 9
# Example 971: Predicted Cluster - 3, True Label - 4
# Example 6687: Predicted Cluster - 0, True Label - 3
# Example 8575: Predicted Cluster - 3, True Label - 9
# Example 2020: Predicted Cluster - 2, True Label - 9
# Example 9054: Predicted Cluster - 1, True Label - 8
# Example 952: Predicted Cluster - 2, True Label - 6
# Example 5359: Predicted Cluster - 0, True Label - 6
# Example 3857: Predicted Cluster - 0, True Label - 1
# Example 5861: Predicted Cluster - 1, True Label - 1
# Example 3145: Predicted Cluster - 0, True Label - 9
# Example 3305: Predicted Cluster - 1, True Label - 9
# Example 3006: Predicted Cluster - 4, True Label - 5
# Example 9001: Predicted Cluster - 3, True Label - 1
# Example 7770: Predicted Cluster - 0, True Label - 9
# Example 7438: Predicted Cluster - 6, True Label - 5
# Example 7942: Predicted Cluster - 3, True Label - 9
# Example 9238: Predicted Cluster - 4, True Label - 9
# Example 1056: Predicted Cluster - 4, True Label - 3
# Example 3154: Predicted Cluster - 1, True Label - 9
# Example 3787: Predicted Cluster - 6, True Label - 3
# Example 9189: Predicted Cluster - 0, True Label - 4
# Example 7825: Predicted Cluster - 2, True Label - 3
# Example 7539: Predicted Cluster - 5, True Label - 5
# Example 7231: Predicted Cluster - 3, True Label - 8
